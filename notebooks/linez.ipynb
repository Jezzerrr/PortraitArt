# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from pathlib import Path
PROJECT_ROOT = Path().resolve().parent

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import importlib
from PIL import Image

# %%
from src.general_functions import *
from src.hatch_job import *
from src.parallel_universe import *

# %% [markdown]
# # Load source material

# %% [markdown]
# target_size=500/1000, move_vertical=0.8, move_horizontal=1, zoom=0.8

# %%
input_image_path = PROJECT_ROOT / "input" / "1705_JesseMetz1439.jpg"
# input_image_path = PROJECT_ROOT / "input" / "input_square.png"
# input_image = extract_square(input_image_path, target_size=1000, move_vertical=.8, move_horizontal=1.05, zoom=.8)

# input_image_path = PROJECT_ROOT / "input" / "gezin" / "Duinrell_1.jpeg"
# input_image_path = PROJECT_ROOT / "input" / "gezin" / "EmiLukA_opastoel.jpeg"
# input_image_path = PROJECT_ROOT / "input" / "gezin" / "JesEmLu_1.jpeg"
# input_image_path = PROJECT_ROOT / "input" / "gezin" / "JesEmLu_2.jpeg"
input_image_path = PROJECT_ROOT / "input" / "gezin" / "JesEmLu_3.jpeg"
# input_image_path = PROJECT_ROOT / "input" / "family" / "Adriana met Emil.jpeg"
# input_image_path = PROJECT_ROOT / "input" / "family" / "Cathelijne en Jesse 1.jpeg"
# input_image_path = PROJECT_ROOT / "input" / "family" / "Cathelijne en Jesse 2.jpeg"
# input_image_path = PROJECT_ROOT / "input" / "family" / "Cato2.jpeg"

# input_image = extract_square(input_image_path, target_size=1000)
# input_image = extract_image(input_image_path, target_size=1000)
input_image = Image.open(input_image_path)

print (input_image.size)
# input_image
# Out:
# (1200, 900)

# %% [markdown]
# # Hatch

# %%
stripe_image = image_to_stripes(
    input_image,
    angle=-20,
    n_candidates=10000,
    darkness_power=1.5,
    darkness_threshold=0.25,
    min_length=1,
    max_length=300,
    line_width=3,
)
# stripe_image

# %% [raw]
# save_image_with_unique_name(stripe_image, output_subfolder='linez')

# %% [raw]
# for angle in range(0, 361, 10):
#     stripe_image = image_to_stripes(
#         input_image,
#         angle=angle,
#         n_candidates=1500,
#         darkness_threshold=0.25,
#         min_length=1,
#         max_length=3000,
#         line_width=10,
#     )
#     save_image_with_unique_name(stripe_image, output_subfolder='linez/rotations/1500_025_1_3000_10', output_filename=f'profile_JM_stripes_angle_{angle}')

# %% [markdown]
# # Parallelll

# %%
line_image = image_to_parallel_lines(
    input_image,
    angle=-35,
    line_spacing=8,
    darkness_threshold=0.45,
    sample_step=2,
    min_segment_length=3,
    line_width=2,
    draw_markers=False,
)
# line_image

# %% [raw]
# save_image_with_unique_name(line_image, output_subfolder='linez')

# %%
marker_image = image_to_parallel_lines(
    input_image,
    angle=15,
    line_spacing=8,
    darkness_threshold=0.35,
    sample_step=2,
    min_segment_length=3,
    line_width=2,
    draw_markers=True,
    marker_size=2,
)
# marker_image
