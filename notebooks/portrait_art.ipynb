# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from pathlib import Path
PROJECT_ROOT = Path().resolve().parent

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import importlib
from PIL import Image

# %%
from src.general_functions import *
from src.patchy_business import *

# %% [markdown]
# # Load source material

# %% [markdown]
# target_size=500/1000, move_vertical=0.8, move_horizontal=1, zoom=0.8

# %%
input_image_path = PROJECT_ROOT / "input" / "1705_JesseMetz1439.jpg"
input_image = extract_square(input_image_path, target_size=300, move_vertical=.8, move_horizontal=1, zoom=.8)
# input_image = extract_square(input_image_path)

# input_image

# %%
output_image = swap_random_patches(
    input_image,
    patch_fraction=0.5,
    n_swaps=2,
)

# output_image
# Out:
# Patch fraction is too big.

# %%
output_image = swap_random_circles(
    input_image,
    patch_fraction=0.5,
    n_swaps=1,
)

output_image
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 output_image = swap_random_circles(
#       2     input_image,
#       3     patch_fraction=0.5,
#       4     n_swaps=1,
#
# File <string>:14, in swap_random_circles(img, patch_fraction, n_swaps, seed)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\random.py:332, in Random.randint(self, a, b)
#     329         raise ValueError(f"empty range in randrange({start}, {stop}, {step})")
#     330     return istart + istep * self._randbelow(n)
# --> 332 def randint(self, a, b):
#     333     """Return random integer in range [a, b], including both end points.
#     334     """
#     336     return self.randrange(a, b+1)
#
# KeyboardInterrupt:
