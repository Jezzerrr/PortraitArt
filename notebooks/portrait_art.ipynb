# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from pathlib import Path
PROJECT_ROOT = Path().resolve().parent

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import importlib
from PIL import Image

# %%
from src.general_functions import *
from src.patchy_business import *
from src.spin_cycle import *
from src.dotty_affair import *

# %% [markdown]
# # Load source material

# %% [markdown]
# target_size=500/1000, move_vertical=0.8, move_horizontal=1, zoom=0.8

# %%
input_image_path = PROJECT_ROOT / "input" / "1705_JesseMetz1439.jpg"
input_image = extract_square(input_image_path, target_size=1000, move_vertical=.8, move_horizontal=1.05, zoom=.8)

# input_image_path = PROJECT_ROOT / "input" / "others" / "elisabeth_ruijgrok_2.jpg"
# input_image = extract_square(input_image_path, target_size=1000)

# input_image_path = PROJECT_ROOT / "input" / "gezin" / "Duinrell_1.jpeg"
# input_image_path = PROJECT_ROOT / "input" / "gezin" / "EmiLukA_opastoel.jpeg"
input_image = Image.open(input_image_path)

# input_image

# %% [markdown]
# # Swap Patches

# %% [raw]
# output_image = swap_random_patches(
#     input_image,
#     patch_fraction=0.3,
#     n_swaps=2,
# )
#
# output_image

# %% [raw]
# output_image = swap_random_circles(
#     input_image,
#     patch_fraction=0.3,
#     n_swaps=1,
# )
#
# output_image

# %% [markdown]
# # Rotate circles

# %%
seed = None
random.seed(seed)

# %%
circle_image = input_image

circle_image = rotate_random_circle(circle_image, patch_fraction=.5, angle=22.5)
circle_image = rotate_random_circle(circle_image, patch_fraction=.5, angle=22.5)
circle_image = rotate_random_circle(circle_image, patch_fraction=.5, angle=22.5)
circle_image = rotate_random_circle(circle_image, patch_fraction=.5, angle=22.5)
circle_image
# Out:
# <PIL.Image.Image image mode=RGB size=2844x1600>

# %% [raw]
# save_image_with_unique_name(circle_image, output_subfolder='others/spin_cycle')

# %%
img = input_image
img = swap_random_circles(img, 0.08, n_swaps=20, seed=46)
img = rotate_random_circle(img, 0.2, angle=30)
# img
